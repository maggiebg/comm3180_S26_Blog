# %% [raw]
# ---
# title: "Dataset of the Week #1: The Weather in Philadelphia"
# author: Maggie
# date: 1/28/2026
# categories:
#   - DOW
#   - Weather
#   - Python
# ---

# %% [markdown]
# ### My post

# %%
print('This is some code')
# Out:
# This is some code

# %% [markdown]
# ---
#
#
#
# The Next Section
#
#
#
# ---
