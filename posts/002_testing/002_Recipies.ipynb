# %% [raw]
# ---
# title: "Maggie's Favorite Recipes"
# description: "How Maggie utilizes her kitchen as a sophomore living in Harnwell."
# author: "Maggie Goldman"
# date: "1/28/2026"
# categories:
#   - Food
#   - Cooking
#   - College
# ---

# %% [markdown]
# ### How Maggie cooks in the Harnwell kitchen:
# * Cooking can be hard for college students, but Maggie has it covered!
